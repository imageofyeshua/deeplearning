# %%
# import libraries
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# %%
# "manually" in numpy

# the list of numbers
z = [1,2,3]

# compute the softmax result
num = np.exp(z)
den = np.sum( np.exp(z) )
sigma = num / den

print(sigma)
print(np.sum(sigma))
# Out:
# [0.09003057 0.24472847 0.66524096]
# 1.0

# %%
# repeat with some random integers
q = np.random.randint(-5,high=15,size=25)
print(q)

# compute the softmax result
num = np.exp(q)
den = np.sum( num )
sigma = num / den

# compare
plt.plot(q,sigma,'ko')
plt.xlabel('Original number (z)')
plt.ylabel('Softmaxified $\\sigma$')
plt.yscale('log')
plt.title('$\\sum\\sigma$ = %g' %np.sum(sigma))
plt.show()
# Out:
# [13 -5 11 12  4  7 10 14  1 10 10  2 14  8  5 -3  8  6 -2  4  3 -2 14 -4
#  -5]

# %%
# slightly more involved using torch.nn

# create an instance of the softmax activation class
softfun = nn.Softmax(dim=0)

# then apply the data to that function
sigmaT = softfun( torch.Tensor(q) )

# now we get the results
print(sigmaT)
# Out:
# tensor([1.0178e-01, 1.5501e-09, 1.3775e-02, 3.7443e-02, 1.2561e-05, 2.5229e-04,
#         5.0674e-03, 2.7667e-01, 6.2537e-07, 5.0674e-03, 5.0674e-03, 1.6999e-06,
#         2.7667e-01, 6.8580e-04, 3.4144e-05, 1.1454e-08, 6.8580e-04, 9.2813e-05,
#         3.1135e-08, 1.2561e-05, 4.6209e-06, 3.1135e-08, 2.7667e-01, 4.2137e-09,
#         1.5501e-09])

# %%
# show that they are the same
plt.plot(sigma,sigmaT,'ko')
plt.xlabel('Manual softmax')
plt.ylabel('Pytorch nn.Softmax')
plt.title(f'The two methods correlate at r={np.corrcoef(sigma,sigmaT)[0,1]}')
plt.show()
